# %% [markdown]
# 优化后的相移
# $\Phi=diag[e^{j\theta_1}, \dots e^{j\theta_i}]$

# %%
import numpy as np
phi = np.load('../optimized_phase.npy') # diag [theta_1, theta_2 ...]
phi
# Out:
# array([-0.78339356, -0.5597459 , -0.3358001 , -0.11189984,  0.11179992,
#         0.33565024,  0.5593471 ,  0.78329253, -0.78349286, -0.55979526,
#        -0.3358002 , -0.11184983,  0.112     ,  0.3357    ,  0.5593967 ,
#         0.7832448 , -0.78359187, -0.5597955 , -0.33559972, -0.11179992,
#         0.112     ,  0.33564946,  0.5592975 ,  0.783245  , -0.78354305,
#        -0.55969584, -0.3355481 , -0.112     ,  0.112     ,  0.33540055,
#         0.5592975 ,  0.7833442 , -0.78359216, -0.5597456 , -0.33564946,
#        -0.112     ,  0.112     ,  0.33535   ,  0.55939674,  0.78344387,
#        -0.78359187, -0.55974567, -0.33584887, -0.112     ,  0.11189987,
#         0.33564946,  0.55974585,  0.7833447 , -0.7835941 , -0.55969626,
#        -0.33599848, -0.11199997,  0.11179997,  0.33594897,  0.55964667,
#         0.7833468 , -0.78359413, -0.5596445 , -0.3360482 , -0.11194992,
#         0.11194994,  0.33584973,  0.5595478 ,  0.78339404], dtype=float32)

# %%
import math
for i in range(len(phi)):
    phi[i] = round(math.degrees(phi[i]), 2)
phi
# Out:
# array([-44.89, -32.07, -19.24,  -6.41,   6.41,  19.23,  32.05,  44.88,
#        -44.89, -32.07, -19.24,  -6.41,   6.42,  19.23,  32.05,  44.88,
#        -44.9 , -32.07, -19.23,  -6.41,   6.42,  19.23,  32.05,  44.88,
#        -44.89, -32.07, -19.23,  -6.42,   6.42,  19.22,  32.05,  44.88,
#        -44.9 , -32.07, -19.23,  -6.42,   6.42,  19.21,  32.05,  44.89,
#        -44.9 , -32.07, -19.24,  -6.42,   6.41,  19.23,  32.07,  44.88,
#        -44.9 , -32.07, -19.25,  -6.42,   6.41,  19.25,  32.07,  44.88,
#        -44.9 , -32.07, -19.25,  -6.41,   6.41,  19.24,  32.06,  44.89],
#       dtype=float32)
